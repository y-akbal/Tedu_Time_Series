# %% [markdown]
# [![Open in Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/y-akbal/Tedu_Time_Series/blob/main/W6/W6P2.5.ipynb)

# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
def return_time_series_lin_trend(n :int, mu: float) -> list:
    return [mu*i+10*np.random.randn() for i in range(n)]

# %%
lt_s = return_time_series_lin_trend(1000, mu = 0.1)

# %%
plt.plot(lt_s)   ### you see there is an obvious deterministic trend, to make sure this let's apply KPSS test

# %%
#statsmodels.tsa.stattools.kpss
import statsmodels
from statsmodels.tsa.stattools import kpss

# %%
kpss([i for i in range(1000)], nlags= 25, regression = "ct")
# Out:
# (9.297926851340794,
#  0.01,
#  25,
#  {'10%': 0.119, '5%': 0.146, '2.5%': 0.176, '1%': 0.216})
