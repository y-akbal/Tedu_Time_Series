# %% [markdown]
# [![Open in Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/y-akbal/Tedu_Time_Series/blob/main/W6/W6P5ipynb)

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %%
import statsmodels
from statsmodels.tsa import stattools

# %%
# !pip install yfinance
# !pip install yahoofinancials
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      |████████████████████████████████| 62 kB 1.1 MB/s
# ...
#   Attempting uninstall: requests
#     Found existing installation: requests 2.23.0
#     Uninstalling requests-2.23.0:
#       Successfully uninstalled requests-2.23.0
# ...
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#   Created wheel for yahoofinancials: filename=yahoofinancials-1.6-py3-none-any.whl size=15192 sha256=266db8bc53c242e82b49bcf0760752fcccb779ec0b95d8d2bee4d5529c1f37d0
#   Stored in directory: /root/.cache/pip/wheels/4b/63/46/e7110bfee88685fe69e338d1b14d1748921862aa57b6705b60
# Successfully built yahoofinancials
# ...

# %%
import pandas as pd
import yfinance as yf
from yahoofinancials import YahooFinancials

# %%
yf.download("BTC-USD")    #### Let's do some fancy thing, and go reach pal! I known you are about to do it!
# Out:
# [*********************100%***********************]  2 of 2 completed
#
# 1 Failed download:
# - CRUDE: No data found, symbol may be delisted
#            Adj Close            Close             High              Low  \
#                CRUDE        OIL CRUDE        OIL CRUDE        OIL CRUDE
# Date
# 2011-04-21       NaN  50.349998   NaN  50.349998   NaN  50.349998   NaN
# 2011-04-25       NaN  50.049999   NaN  50.049999   NaN  50.570000   NaN
# 2011-04-26       NaN  50.299999   NaN  50.299999   NaN  50.430000   NaN
# 2011-04-27       NaN  50.810001   NaN  50.810001   NaN  50.849998   NaN
# 2011-04-28       NaN  50.700001   NaN  50.700001   NaN  51.160000   NaN
# ...              ...        ...   ...        ...   ...        ...   ...
# 2022-09-26       NaN  27.379999   NaN  27.379999   NaN  28.670000   NaN
# 2022-09-27       NaN  27.959999   NaN  27.959999   NaN  28.250000   NaN
# 2022-09-28       NaN  29.049999   NaN  29.049999   NaN  29.230000   NaN
# ...
