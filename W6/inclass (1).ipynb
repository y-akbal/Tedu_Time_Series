# %% [markdown]
# [![Open in Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/y-akbal/Tedu_Time_Series/blob/main/W6/inclass.ipynb)

# %%
# !pip install yfinance
# !pip install yahoofinancials
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      |████████████████████████████████| 62 kB 1.6 MB/s
# ...
#   Attempting uninstall: requests
#     Found existing installation: requests 2.23.0
#     Uninstalling requests-2.23.0:
#       Successfully uninstalled requests-2.23.0
# ...
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#   Created wheel for yahoofinancials: filename=yahoofinancials-1.6-py3-none-any.whl size=15191 sha256=a0355b40e5cbd22a4102111dfbb41232c13a007af3d0f6bbe9c3912b2772a166
#   Stored in directory: /root/.cache/pip/wheels/4b/63/46/e7110bfee88685fe69e338d1b14d1748921862aa57b6705b60
# Successfully built yahoofinancials
# ...

# %%
import pandas as pd
import yfinance as yf
from yahoofinancials import YahooFinancials

# %% [markdown]
# ### At this point [click here ](https://finance.yahoo.com/crypto/) to scrape some data. You will go rich! What yo'll waitin' for?

# %%
data = yf.download('Oil')
# Out:
# [*********************100%***********************]  1 of 1 completed

# %%
data
# Out:
#                  Open       High        Low      Close  Adj Close  Volume
# Date
# 2011-04-21  49.939999  50.349998  49.900002  50.349998  50.349998   10500
# 2011-04-25  50.570000  50.570000  49.910000  50.049999  50.049999   14900
# 2011-04-26  50.180000  50.430000  50.099998  50.299999  50.299999   15000
# 2011-04-27  50.349998  50.849998  49.799999  50.810001  50.810001   35200
# 2011-04-28  50.779999  51.160000  50.169998  50.700001  50.700001   44800
# ...               ...        ...        ...        ...        ...     ...
# 2022-11-11  32.430000  32.689999  32.150002  32.590000  32.590000   24400
# 2022-11-14  32.230000  32.490002  31.260000  31.280001  31.280001   36900
# 2022-11-15  31.270000  32.580002  31.240000  31.930000  31.930000   34800
# 2022-11-16  31.700001  31.700001  31.120001  31.309999  31.309999   23500
# 2022-11-17  31.049999  31.070000  30.330000  30.530001  30.530001   96100
#
# [2915 rows x 6 columns]
