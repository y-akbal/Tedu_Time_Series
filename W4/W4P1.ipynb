# %% [markdown]
# [![Open in Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/y-akbal/Tedu_Time_Series/blob/main/W4/W4P1.ipynb)

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
A = 0.5*np.random.randn(100000)
theta_1 = np.random.randn()
c_0 = np.random.randn()

# %%
def create_ma1(A, theta_1, c_0 = 0):
  L = []
  L.append(c_0)
  f = lambda at, at1 : c_0+at - theta_1*at1
  for i, _ in enumerate(A):
    try:  ###we use exception blocks to pertain interpreter thrown an error!
      L.append(f(A[i+1], A[i]))
    except Exception:
      break
  return L

# %%
ma1 = create_ma1(A, theta_1, c_0 = 0)
plt.figure(figsize = (15,3))
plt.plot(ma1, label = "MA(1) Model")
plt.legend(fontsize = 10)
plt.show()

# %%
np.var(A)
# Out:
# 0.24995701524220745

# %%
np.var(ma1)
# Out:
# 0.2870170657765403

# %% [markdown]
# See these two guys are almost the same, above we have the variance of the series. Below we have the variance coming from the formula!

# %%
(1+(theta_1)**2)*np.var(A)
# Out:
# 0.2867928742701369
