# %% [markdown]
# [![Open in Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/y-akbal/Tedu_Time_Series/blob/main/W13/W13P2.ipynb)

# %%
import os
from google.colab import drive
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import statsmodels
from statsmodels.tsa.seasonal import seasonal_decompose

# %%
def to_dataframe(text: str):
    """
    
    Parameters
    ----------
    text : this dude is a text file (a string actually).

    Returns
    -------
    Pandas dataframe

    """    
    L = []
    headers = []
    with open(text) as file:
        T = file.readlines()
        for i, t in enumerate(T):
            if i == 0:
                for header  in t[:-1].split():
                  headers.append(header)      
            else:
                L.append(t[0:-1].split())
    L = pd.DataFrame(L)
    
    L = L.apply(pd.to_numeric)
    L.columns = headers
    return L
def download_data():  ### This dude will download the dataset from the directory directly!
  # !wget https://faculty.chicagobooth.edu/-/media/faculty/ruey-s-tsay/teaching/introts/ch2data.zip
  # !unzip "/content/ch2data.zip" -d "/content/ch2data/"
  if not os.getcwd() == '/content/ch2data':
    os.chdir("ch2data")
  else:
    print(f"Current directory is now {os.getcwd()}")

download_data()
# Out:
# --2022-12-30 08:08:33--  https://faculty.chicagobooth.edu/-/media/faculty/ruey-s-tsay/teaching/introts/ch2data.zip
# Resolving faculty.chicagobooth.edu (faculty.chicagobooth.edu)... 128.135.211.142
# Connecting to faculty.chicagobooth.edu (faculty.chicagobooth.edu)|128.135.211.142|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 557379 (544K) [application/x-zip-compressed]
# Saving to: ‘ch2data.zip’
#
# ch2data.zip         100%[===================>] 544.32K   830KB/s    in 0.7s
#
# 2022-12-30 08:08:33 (830 KB/s) - ‘ch2data.zip’ saved [557379/557379]
#
# Archive:  /content/ch2data.zip
# replace /content/ch2data/d-aapl0305.txt? [y]es, [n]o, [A]ll, [N]one, [r]ename: Y
#   inflating: /content/ch2data/d-aapl0305.txt
# replace /content/ch2data/d-ibm3dx7008.txt? [y]es, [n]o, [A]ll, [N]one, [r]ename: y
#   inflating: /content/ch2data/d-ibm3dx7008.txt
# replace /content/ch2data/d-sp55008.txt? [y]es, [n]o, [A]ll, [N]one, [r]ename: N
# Current directory is now /content/ch2data

# %%
data = to_dataframe("q-ko-earns8309.txt")["value"]
# Out:
# 0     0.0375
# 1     0.0492
# 2     0.0463
# 3     0.0379
# 4     0.0425
# 5     0.0583
# 6     0.0558
# 7     0.0417
# 8     0.0450
# 9     0.0625
# 10    0.0617
# 11    0.0463
# 12    0.0525
# 13    0.0725
# 14    0.0750
# 15    0.0588
# 16    0.0612
# 17    0.0875
# 18    0.0900
# 19    0.0650
# Name: value, dtype: float64

# %%
data = data.apply(np.log)
